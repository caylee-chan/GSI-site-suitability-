# %%
import shutil

# %%
# Mean precipitation rate - ssp2 2025

# Reproject
ssp2_2025_mean_prcp_reproject = './data/projected_precip/precip_ssp2_2025/ssp2_2025_prcp_rate_reprojected.tif'
ssp2_2025_mean_prcp_reproject_work = '/work/hdd/bfqp/cchan2/preprocessing_rasters/prcp_rate_ssp2_2025/ssp2_2025_prcp_rate_reprojected.tif'
shutil.copy(ssp2_2025_mean_prcp_reproject, ssp2_2025_mean_prcp_reproject_work)

# Coregister
ssp2_2025_mean_prcp_coregister = './data/projected_precip/precip_ssp2_2025/ssp2_2025_prcp_rate_coregistered.tif'
ssp2_2025_mean_prcp_coregister_work = '/work/hdd/bfqp/cchan2/preprocessing_rasters/prcp_rate_ssp2_2025/ssp2_2025_prcp_rate_coregistered.tif'
shutil.copy(ssp2_2025_mean_prcp_coregister, ssp2_2025_mean_prcp_coregister_work)
# Out:
# '/work/hdd/bfqp/cchan2/preprocessing_rasters/prcp_rate_ssp2_2025/ssp2_2025_prcp_rate_coregistered.tif'

# %%
# Mean precipitation rate - ssp2 2050

# Reproject
ssp2_2050_mean_prcp_reproject = './data/projected_precip/precip_ssp2_2050/ssp2_2050_prcp_rate_reprojected.tif'
ssp2_2050_mean_prcp_reproject_work = '/work/hdd/bfqp/cchan2/preprocessing_rasters/prcp_rate_ssp2_2050/ssp2_2050_prcp_rate_reprojected.tif'
shutil.copy(ssp2_2050_mean_prcp_reproject, ssp2_2050_mean_prcp_reproject_work)

# Coregister
ssp2_2050_mean_prcp_coregister = './data/projected_precip/precip_ssp2_2050/ssp2_2050_prcp_rate_coregistered.tif'
ssp2_2050_mean_prcp_coregister_work = '/work/hdd/bfqp/cchan2/preprocessing_rasters/prcp_rate_ssp2_2050/ssp2_2050_prcp_rate_coregistered.tif'
shutil.copy(ssp2_2050_mean_prcp_coregister, ssp2_2050_mean_prcp_coregister_work)
# Out:
# '/work/hdd/bfqp/cchan2/preprocessing_rasters/prcp_rate_ssp2_2050/ssp2_2050_prcp_rate_coregistered.tif'

# %%
# Mean precipitation rate - ssp5 2050

# Reproject
ssp5_2050_mean_prcp_reproject = './data/projected_precip/precip_ssp5_2050/ssp5_2050_prcp_rate_reprojected.tif'
ssp5_2050_mean_prcp_reproject_work = '/work/hdd/bfqp/cchan2/preprocessing_rasters/prcp_rate_ssp5_2050/ssp5_2050_prcp_rate_reprojected.tif'
shutil.copy(ssp5_2050_mean_prcp_reproject, ssp5_2050_mean_prcp_reproject_work)

# Coregister
ssp5_2050_mean_prcp_coregister = './data/projected_precip/precip_ssp5_2050/ssp5_2050_prcp_rate_coregistered.tif'
ssp5_2050_mean_prcp_coregister_work = '/work/hdd/bfqp/cchan2/preprocessing_rasters/prcp_rate_ssp5_2050/ssp5_2050_prcp_rate_coregistered.tif'
shutil.copy(ssp5_2050_mean_prcp_coregister, ssp5_2050_mean_prcp_coregister_work)
# Out:
# '/work/hdd/bfqp/cchan2/preprocessing_rasters/prcp_rate_ssp5_2050/ssp5_2050_prcp_rate_coregistered.tif'

# %%
# Mean precipitation standard deviation - ssp2 2025

# Reproject
ssp2_2025_sd_prcp_reproject = './data/projected_precip/precip_ssp2_2025/ssp2_2025_standard_dev_prcp_rate_reprojected.tif'
ssp2_2025_sd_prcp_reproject_work = '/work/hdd/bfqp/cchan2/preprocessing_rasters/prcp_sd_ssp2_2025/ssp2_2025_standard_dev_prcp_rate_reprojected.tif'
shutil.copy(ssp2_2025_sd_prcp_reproject, ssp2_2025_sd_prcp_reproject_work)

# Coregister
ssp2_2025_sd_prcp_coregister = './data/projected_precip/precip_ssp2_2025/ssp2_2025_standard_dev_prcp_rate_coregister.tif'
ssp2_2025_sd_prcp_coregister_work = '/work/hdd/bfqp/cchan2/preprocessing_rasters/prcp_sd_ssp2_2025/ssp2_2025_standard_dev_prcp_rate_coregister.tif'
shutil.copy(ssp2_2025_sd_prcp_coregister, ssp2_2025_sd_prcp_coregister_work)
# Out:
# '/work/hdd/bfqp/cchan2/preprocessing_rasters/prcp_sd_ssp2_2025/ssp2_2025_standard_dev_prcp_rate_coregister.tif'

# %%
# Mean precipitation standard deviation - ssp2 2050

# Reproject
ssp2_2050_sd_prcp_reproject = './data/projected_precip/precip_ssp2_2050/ssp2_2050_standard_dev_prcp_rate_reprojected.tif'
ssp2_2050_sd_prcp_reproject_work = '/work/hdd/bfqp/cchan2/preprocessing_rasters/prcp_sd_ssp2_2050/ssp2_2050_standard_dev_prcp_rate_reprojected.tif'
shutil.copy(ssp2_2050_sd_prcp_reproject, ssp2_2050_sd_prcp_reproject_work)

# Coregister
ssp2_2050_sd_prcp_coregister = './data/projected_precip/precip_ssp2_2050/ssp2_2050_standard_dev_prcp_rate_coregistered.tif'
ssp2_2050_sd_prcp_coregister_work = '/work/hdd/bfqp/cchan2/preprocessing_rasters/prcp_sd_ssp2_2050/ssp2_2050_standard_dev_prcp_rate_coregistered.tif'
shutil.copy(ssp2_2050_sd_prcp_coregister, ssp2_2050_sd_prcp_coregister_work)
# Out:
# '/work/hdd/bfqp/cchan2/preprocessing_rasters/prcp_sd_ssp2_2050/ssp2_2050_standard_dev_prcp_rate_coregistered.tif'

# %%
# Mean precipitation standard deviation - ssp5 2050

# Reproject
ssp5_2050_sd_prcp_reproject = './data/projected_precip/precip_ssp5_2050/ssp5_2050_standard_dev_prcp_rate_reprojected.tif'
ssp5_2050_sd_prcp_reproject_work = '/work/hdd/bfqp/cchan2/preprocessing_rasters/prcp_sd_ssp5_2050/ssp5_2050_standard_dev_prcp_rate_reprojected.tif'
shutil.copy(ssp5_2050_sd_prcp_reproject, ssp5_2050_sd_prcp_reproject_work)

# Coregister
ssp5_2050_sd_prcp_coregister = './data/projected_precip/precip_ssp5_2050/ssp5_2050_standard_dev_prcp_rate_coregistered.tif'
ssp5_2050_sd_prcp_coregister_work = '/work/hdd/bfqp/cchan2/preprocessing_rasters/prcp_sd_ssp5_2050/ssp5_2050_standard_dev_prcp_rate_coregistered.tif'
shutil.copy(ssp5_2050_sd_prcp_coregister, ssp5_2050_sd_prcp_coregister_work)
# Out:
# '/work/hdd/bfqp/cchan2/preprocessing_rasters/prcp_sd_ssp5_2050/ssp5_2050_standard_dev_prcp_rate_coregistered.tif'

# %%
# Land cover

# Profile update
lc_profile_update = './data/land_cover/land_cover_profile_update.tif'
lc_profile_update_work = '/work/ndd/bfqp/cchan2/preprocessing_rasters/land_cover/land_cover_profile_update.tif'

shutil.copy(lc_profile_update, lc_profile_update_work)

# Reprojection
lc_reproject = './data/land_cover/land_cover_reprojected.tif'
lc_reproject_work = '/work/ndd/bfqp/cchan2/preprocessing_rasters/land_cover/land_cover_reprojected.tif'

shutil.copy(lc_reproject, lc_profile_update_work)

# Co-register
lc_coregister = './data/land_cover/land_cover_coregistered.tif'
lc_coregister_work = '/work/ndd/bfqp/cchan2/preprocessing_rasters/land_cover/land_cover_coregistered.tif'

# Match
