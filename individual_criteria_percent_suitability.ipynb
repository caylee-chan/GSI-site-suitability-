# %%
import numpy as np 
import rasterio
from rasterio.mask import mask
from tqdm import tqdm

# %%
#### Land cover -------------------------------------------------------------------------------------------------------

# %%
# % Suitable land cover
# % cells == 10

land_cover = './data/land_cover/land_cover_standardized.tif'

total_high_suitability = 0
total_nodata = 0

with rasterio.open(land_cover) as src:

    # Total number of blocks
    total_blocks = sum(1 for _ in src.block_windows(1))
    print(f'Total blocks: {total_blocks}')

    for ji, window in tqdm(src.block_windows(1), total = total_blocks, desc = 'Block window processing'):
        data = src.read(1, window = window, masked = True)

        #total_high_suitability += np.count_nonzero((data == 10) | (data == 4) | (data == 0))
        total_high_suitability += np.count_nonzero(data == 10) # Counts total number of cells == 10

        total_nodata += np.sum(data.mask) # Calculates the total number of nodata cells

    all_cells = src.width * src.height # Total number of cells

    all_NON_nodata_cells = all_cells - total_nodata # Total number of cells WITH valid data

    percent_high_suitability = total_high_suitability / all_NON_nodata_cells 
    print(f'Total number of valid data cells: {all_NON_nodata_cells}')
    print(f'% high suitability (10): {percent_high_suitability}')
# Out:
# Total blocks: 910224
# Block window processing: 100%|██████████| 910224/910224 [04:48<00:00, 3153.24it/s]
# Total number of valid data cells: 8572081618
# % high suitability (10): 0.07053847757705753

# %%
#### Hydrologic soil group --------------------------------------------------------------------------------------------

# %%
# % Suitable hydrologic soil group
# % cells == 10

hsg = './data/SSURGO_raw/hsg/hsg_FINAL_composite_standardized.tif'

total_high_suitability = 0
total_nodata = 0

with rasterio.open(hsg) as src:

    # Total number of blocks
    total_blocks = sum(1 for _ in src.block_windows(1))
    print(f'Total blocks: {total_blocks}')

    for ji, window in tqdm(src.block_windows(1), total = total_blocks, desc = 'Block window processing'):
        data = src.read(1, window = window, masked = True)

        total_high_suitability += np.count_nonzero(data == 10) # Counts total number of cells == 10

        total_nodata += np.sum(data.mask) # Calculates the total number of nodata cells

    all_cells = src.width * src.height # Total number of cells

    all_NON_nodata_cells = all_cells - total_nodata # Total number of cells WITH valid data

    percent_high_suitability = total_high_suitability / all_NON_nodata_cells 
    print(f'Total number of valid data cells: {all_NON_nodata_cells}')
    print(f'% high suitability (10): {percent_high_suitability}')
# Out:
# Total blocks: 910224
# Block window processing: 100%|██████████| 910224/910224 [04:57<00:00, 3058.33it/s]
# Total number of valid data cells: 8572323082
# % high suitability (10): 0.3024872600106231

# %%
#### Slope ------------------------------------------------------------------------------------------------------------

# %%
# % Suitable slope
# % cells == 10

slope = './data/slope/slope_standardized.tif'

total_high_suitability = 0
total_nodata = 0

with rasterio.open(slope) as src:

    # Total number of blocks
    total_blocks = sum(1 for _ in src.block_windows(1))
    print(f'Total blocks: {total_blocks}')

    for ji, window in tqdm(src.block_windows(1), total = total_blocks, desc = 'Block window processing'):
        data = src.read(1, window = window, masked = True)

        total_high_suitability += np.count_nonzero(data == 10) # Counts total number of cells == 10

        total_nodata += np.sum(data.mask) # Calculates the total number of nodata cells

    all_cells = src.width * src.height # Total number of cells

    all_NON_nodata_cells = all_cells - total_nodata # Total number of cells WITH valid data

    percent_high_suitability = total_high_suitability / all_NON_nodata_cells 
    print(f'Total number of valid data cells: {all_NON_nodata_cells}')
    print(f'% high suitability (10): {percent_high_suitability}')
# Out:
# Total blocks: 910224
# Block window processing: 100%|██████████| 910224/910224 [04:53<00:00, 3104.91it/s]
# Total number of valid data cells: 8572264851
# % high suitability (10): 0.9354264844097268

# %%
#### Watershed impairment ---------------------------------------------------------------------------------------------

# %%
# % Suitable watershed impairment
# % cells >8 & <=10

impairment = './data/watershed_impairment/impairment_standardized.tif'

total_high_suitability = 0
total_nodata = 0

with rasterio.open(impairment) as src:

    # Total number of blocks
    total_blocks = sum(1 for _ in src.block_windows(1))
    print(f'Total blocks: {total_blocks}')

    for ji, window in tqdm(src.block_windows(1), total = total_blocks, desc = 'Block window processing'):
        data = src.read(1, window = window, masked = True)

        total_high_suitability += np.count_nonzero((data > 8) & (data <= 10)) # Counts total number of cells >8 & <=10

        total_nodata += np.sum(data.mask) # Calculates the total number of nodata cells

    all_cells = src.width * src.height # Total number of cells

    all_NON_nodata_cells = all_cells - total_nodata # Total number of cells WITH valid data

    percent_high_suitability = total_high_suitability / all_NON_nodata_cells 
    print(f'Total number of valid data cells: {all_NON_nodata_cells}')
    print(f'% high suitability (>8 & <=10): {percent_high_suitability}')
# Out:
# Total blocks: 910224
# Block window processing: 100%|██████████| 910224/910224 [05:43<00:00, 2649.63it/s]
# Total number of valid data cells: 8569761530
# % high suitability (>8 & <=10): 0.08245049124488299

# %%
#### Mean precipitation rate SSP2, 2025 -------------------------------------------------------------------------------

# %%
# % Suitable precip ssp2 2025
# % cells >8 & <=10

prcip_ssp2_2025 = './data/projected_precip/precip_ssp2_2025/ssp2_2025_prcp_rate_standardized.tif'

total_high_suitability = 0
total_nodata = 0

with rasterio.open(prcip_ssp2_2025) as src:

    # Total number of blocks
    total_blocks = sum(1 for _ in src.block_windows(1))
    print(f'Total blocks: {total_blocks}')

    for ji, window in tqdm(src.block_windows(1), total = total_blocks, desc = 'Block window processing'):
        data = src.read(1, window = window, masked = True)

        total_high_suitability += np.count_nonzero((data > 8) & (data <= 10)) # Counts total number of cells >8 & <=10

        total_nodata += np.sum(data.mask) # Calculates the total number of nodata cells

    all_cells = src.width * src.height # Total number of cells

    all_NON_nodata_cells = all_cells - total_nodata # Total number of cells WITH valid data

    percent_high_suitability = total_high_suitability / all_NON_nodata_cells 
    print(f'Total number of valid data cells: {all_NON_nodata_cells}')
    print(f'% high suitability (>8 & <=10): {percent_high_suitability}')
# Out:
# Total blocks: 910224
# Block window processing: 100%|██████████| 910224/910224 [08:45<00:00, 1731.14it/s]
# Total number of valid data cells: 8572268474
# % high suitability (>8 & <=10): 0.0009312426488055418

# %%
#### Mean precipitation rate SSP2, 2025 -------------------------------------------------------------------------------

# %%
# % Suitable precip ssp2 2050
# % cells >8 & <=10

prcip_ssp2_2050 = './data/projected_precip/precip_ssp2_2050/ssp2_2050_prcp_rate_standardized.tif'

total_high_suitability = 0
total_nodata = 0

with rasterio.open(prcip_ssp2_2050) as src:

    # Total number of blocks
    total_blocks = sum(1 for _ in src.block_windows(1))
    print(f'Total blocks: {total_blocks}')

    for ji, window in tqdm(src.block_windows(1), total = total_blocks, desc = 'Block window processing'):
        data = src.read(1, window = window, masked = True)

        total_high_suitability += np.count_nonzero((data > 8) & (data <= 10)) # Counts total number of cells >8 & <=10

        total_nodata += np.sum(data.mask) # Calculates the total number of nodata cells

    all_cells = src.width * src.height # Total number of cells

    all_NON_nodata_cells = all_cells - total_nodata # Total number of cells WITH valid data

    percent_high_suitability = total_high_suitability / all_NON_nodata_cells 
    print(f'Total number of valid data cells: {all_NON_nodata_cells}')
    print(f'% high suitability (>8 & <=10): {percent_high_suitability}')
# Out:
# Total blocks: 910224
# Block window processing: 100%|██████████| 910224/910224 [09:11<00:00, 1650.86it/s]
# Total number of valid data cells: 8572268474
# % high suitability (>8 & <=10): 0.000945979354775864

# %%
#### Mean precipitation rate SSP5, 2025 -------------------------------------------------------------------------------

# %%
# % Suitable precip ssp5 2050
# % cells >8 & <=10

prcip_ssp5_2050 = './data/projected_precip/precip_ssp5_2050/ssp5_2050_prcp_rate_standardized.tif'

total_high_suitability = 0
total_nodata = 0

with rasterio.open(prcip_ssp5_2050) as src:

    # Total number of blocks
    total_blocks = sum(1 for _ in src.block_windows(1))
    print(f'Total blocks: {total_blocks}')

    for ji, window in tqdm(src.block_windows(1), total = total_blocks, desc = 'Block window processing'):
        data = src.read(1, window = window, masked = True)

        total_high_suitability += np.count_nonzero((data > 8) & (data <= 10)) # Counts total number of cells >8 & <=10

        total_nodata += np.sum(data.mask) # Calculates the total number of nodata cells

    all_cells = src.width * src.height # Total number of cells

    all_NON_nodata_cells = all_cells - total_nodata # Total number of cells WITH valid data

    percent_high_suitability = total_high_suitability / all_NON_nodata_cells 
    print(f'Total number of valid data cells: {all_NON_nodata_cells}')
    print(f'% high suitability (>8 & <=10): {percent_high_suitability}')
# Out:
# Total blocks: 910224
# Block window processing: 100%|██████████| 910224/910224 [08:41<00:00, 1745.65it/s]
# Total number of valid data cells: 8572268474
# % high suitability (>8 & <=10): 0.0009524953662808018

# %%
#### Standard deviation (precipitation rate) SSP2, 2025 ---------------------------------------------------------------

# %%
# % Suitable sd ssp2, 2025
# % cells >8 & <=10

sd_ssp2_2025 = './data/projected_precip/precip_ssp2_2025/ssp2_2025_standard_dev_prcp_rate_standarized.tif'

total_high_suitability = 0
total_nodata = 0

with rasterio.open(sd_ssp2_2025) as src:

    # Total number of blocks
    total_blocks = sum(1 for _ in src.block_windows(1))
    print(f'Total blocks: {total_blocks}')

    for ji, window in tqdm(src.block_windows(1), total = total_blocks, desc = 'Block window processing'):
        data = src.read(1, window = window, masked = True)

        total_high_suitability += np.count_nonzero((data > 8) & (data <= 10)) # Counts total number of cells >8 & <=10

        total_nodata += np.sum(data.mask) # Calculates the total number of nodata cells

    all_cells = src.width * src.height # Total number of cells

    all_NON_nodata_cells = all_cells - total_nodata # Total number of cells WITH valid data

    percent_high_suitability = total_high_suitability / all_NON_nodata_cells 
    print(f'Total number of valid data cells: {all_NON_nodata_cells}')
    print(f'% high suitability (>8 & <=10): {percent_high_suitability}')
# Out:
# Total blocks: 910224
# Block window processing: 100%|██████████| 910224/910224 [08:37<00:00, 1760.04it/s]
# Total number of valid data cells: 8572268474
# % high suitability (>8 & <=10): 0.40672847643245663

# %%
#### Standard deviation (precipitation rate) SSP2, 2050 ---------------------------------------------------------------

# %%
# % Suitable sd ssp2, 2050
# % cells >8 & <=10

sd_ssp2_2050 = './data/projected_precip/precip_ssp2_2050/ssp2_2050_standard_dev_prcp_rate_standardized.tif'

total_high_suitability = 0
total_nodata = 0

with rasterio.open(sd_ssp2_2050) as src:

    # Total number of blocks
    total_blocks = sum(1 for _ in src.block_windows(1))
    print(f'Total blocks: {total_blocks}')

    for ji, window in tqdm(src.block_windows(1), total = total_blocks, desc = 'Block window processing'):
        data = src.read(1, window = window, masked = True)

        total_high_suitability += np.count_nonzero((data > 8) & (data <= 10)) # Counts total number of cells >8 & <=10

        total_nodata += np.sum(data.mask) # Calculates the total number of nodata cells

    all_cells = src.width * src.height # Total number of cells

    all_NON_nodata_cells = all_cells - total_nodata # Total number of cells WITH valid data

    percent_high_suitability = total_high_suitability / all_NON_nodata_cells 
    print(f'Total number of valid data cells: {all_NON_nodata_cells}')
    print(f'% high suitability (>8 & <=10): {percent_high_suitability}')
# Out:
# Total blocks: 910224
# Block window processing: 100%|██████████| 910224/910224 [08:33<00:00, 1772.74it/s]
# Total number of valid data cells: 8572268474
# % high suitability (>8 & <=10): 0.37774978639802226

# %%
#### Standard deviation (precipitation rate) SSP5, 2050 ---------------------------------------------------------------

# %%
# % Suitable sd ssp5, 2050
# % cells >8 & <=10

sd_ssp5_2050 = './data/projected_precip/precip_ssp5_2050/ssp5_2050_standard_dev_prcp_rate_standardized.tif'

total_high_suitability = 0
total_nodata = 0

with rasterio.open(sd_ssp5_2050) as src:

    # Total number of blocks
    total_blocks = sum(1 for _ in src.block_windows(1))
    print(f'Total blocks: {total_blocks}')

    for ji, window in tqdm(src.block_windows(1), total = total_blocks, desc = 'Block window processing'):
        data = src.read(1, window = window, masked = True)

        total_high_suitability += np.count_nonzero((data > 8) & (data <= 10)) # Counts total number of cells >8 & <=10

        total_nodata += np.sum(data.mask) # Calculates the total number of nodata cells

    all_cells = src.width * src.height # Total number of cells

    all_NON_nodata_cells = all_cells - total_nodata # Total number of cells WITH valid data

    percent_high_suitability = total_high_suitability / all_NON_nodata_cells 
    print(f'Total number of valid data cells: {all_NON_nodata_cells}')
    print(f'% high suitability (>8 & <=10): {percent_high_suitability}')
# Out:
# Total blocks: 910224
# Block window processing: 100%|██████████| 910224/910224 [08:32<00:00, 1776.89it/s]
# Total number of valid data cells: 8572268474
# % high suitability (>8 & <=10): 0.47583707117570617

# %%
#### Percent impervious -----------------------------------------------------------------------------------------------

# %%
# % Suitable %impervious
# % cells >8 & <=10

impervious = './data/percent_impervious/impervious_standardized.tif'

total_high_suitability = 0
total_nodata = 0

with rasterio.open(impervious) as src:

    # Total number of blocks
    total_blocks = sum(1 for _ in src.block_windows(1))
    print(f'Total blocks: {total_blocks}')

    for ji, window in tqdm(src.block_windows(1), total = total_blocks, desc = 'Block window processing'):
        data = src.read(1, window = window, masked = True)

        total_high_suitability += np.count_nonzero((data > 8) & (data <= 10)) # Counts total number of cells >8 & <=10

        total_nodata += np.sum(data.mask) # Calculates the total number of nodata cells

    all_cells = src.width * src.height # Total number of cells

    all_NON_nodata_cells = all_cells - total_nodata # Total number of cells WITH valid data

    percent_high_suitability = total_high_suitability / all_NON_nodata_cells 
    print(f'Total number of valid data cells: {all_NON_nodata_cells}')
    print(f'% high suitability (>8 & <=10): {percent_high_suitability}')
# Out:
# Total blocks: 910224
# Block window processing: 100%|██████████| 910224/910224 [05:37<00:00, 2694.41it/s]
# Total number of valid data cells: 8572081618
# % high suitability (>8 & <=10): 0.0024858515060396384

# %%
#### Areas of new/redevelopment: SSP2, 2025 ---------------------------------------------------------------------------

# %%
# % Suitable pop ssp2, 2025
# % cells >8 & <=10

pop_ssp2_2025 = './data/population_density/pop_ssp2_rcp45_2025/ssp2_2025_density_standardized.tif'

total_high_suitability = 0
total_nodata = 0

with rasterio.open(pop_ssp2_2025) as src:

    # Total number of blocks
    total_blocks = sum(1 for _ in src.block_windows(1))
    print(f'Total blocks: {total_blocks}')

    for ji, window in tqdm(src.block_windows(1), total = total_blocks, desc = 'Block window processing'):
        data = src.read(1, window = window, masked = True)

        total_high_suitability += np.count_nonzero((data > 8) & (data <= 10)) # Counts total number of cells >8 & <=10

        total_nodata += np.sum(data.mask) # Calculates the total number of nodata cells

    all_cells = src.width * src.height # Total number of cells

    all_NON_nodata_cells = all_cells - total_nodata # Total number of cells WITH valid data

    percent_high_suitability = total_high_suitability / all_NON_nodata_cells 
    print(f'Total number of valid data cells: {all_NON_nodata_cells}')
    print(f'% high suitability (>8 & <=10): {percent_high_suitability}')
# Out:
# Total blocks: 910224
# Block window processing: 100%|██████████| 910224/910224 [05:28<00:00, 2768.72it/s]
# Total number of valid data cells: 8565061059
# % high suitability (>8 & <=10): 0.003953629258067849

# %%
#### Areas of new/redevelopment: SSP2, 2050 ---------------------------------------------------------------------------

# %%
# % Suitable pop ssp2, 2050
# % cells >8 & <=10

pop_ssp2_2050 = './data/population_density/pop_ssp2_rcp45_2050/ssp2_2050_density_change_standardized.tif'

total_high_suitability = 0
total_nodata = 0

with rasterio.open(pop_ssp2_2050) as src:

    # Total number of blocks
    total_blocks = sum(1 for _ in src.block_windows(1))
    print(f'Total blocks: {total_blocks}')

    for ji, window in tqdm(src.block_windows(1), total = total_blocks, desc = 'Block window processing'):
        data = src.read(1, window = window, masked = True)

        total_high_suitability += np.count_nonzero((data > 8) & (data <= 10)) # Counts total number of cells >8 & <=10

        total_nodata += np.sum(data.mask) # Calculates the total number of nodata cells

    all_cells = src.width * src.height # Total number of cells

    all_NON_nodata_cells = all_cells - total_nodata # Total number of cells WITH valid data

    percent_high_suitability = total_high_suitability / all_NON_nodata_cells 
    print(f'Total number of valid data cells: {all_NON_nodata_cells}')
    print(f'% high suitability (>8 & <=10): {percent_high_suitability}')
# Out:
# Total blocks: 910224
# Block window processing: 100%|██████████| 910224/910224 [05:27<00:00, 2782.37it/s]
# Total number of valid data cells: 8565061059
# % high suitability (>8 & <=10): 0.0005343588292567711

# %%
#### Areas of new/redevelopment: SSP5, 2050 ---------------------------------------------------------------------------

# %%
# % Suitable pop ssp5, 2025
# % cells >8 & <=10

pop_ssp5_2050 = './data/population_density/pop_ssp5_rcp85_2050/ssp5_2050_density_change_standardized.tif'

total_high_suitability = 0
total_nodata = 0

with rasterio.open(pop_ssp5_2050) as src:

    # Total number of blocks
    total_blocks = sum(1 for _ in src.block_windows(1))
    print(f'Total blocks: {total_blocks}')

    for ji, window in tqdm(src.block_windows(1), total = total_blocks, desc = 'Block window processing'):
        data = src.read(1, window = window, masked = True)

        total_high_suitability += np.count_nonzero((data > 8) & (data <= 10)) # Counts total number of cells >8 & <=10

        total_nodata += np.sum(data.mask) # Calculates the total number of nodata cells

    all_cells = src.width * src.height # Total number of cells

    all_NON_nodata_cells = all_cells - total_nodata # Total number of cells WITH valid data

    percent_high_suitability = total_high_suitability / all_NON_nodata_cells 
    print(f'Total number of valid data cells: {all_NON_nodata_cells}')
    print(f'% high suitability (>8 & <=10): {percent_high_suitability}')
# Out:
# Total blocks: 910224
# Block window processing: 100%|██████████| 910224/910224 [05:27<00:00, 2782.81it/s]
# Total number of valid data cells: 8565061059
# % high suitability (>8 & <=10): 0.005309373008172037

# %%
#### Social improvement potential -------------------------------------------------------------------------------------

# %%
# % Suitable social improvement potential
# % cells >8 & <=10

svi = './data/svi/svi_standardized.tif'

total_high_suitability = 0
total_nodata = 0

with rasterio.open(svi) as src:

    # Total number of blocks
    total_blocks = sum(1 for _ in src.block_windows(1))
    print(f'Total blocks: {total_blocks}')

    for ji, window in tqdm(src.block_windows(1), total = total_blocks, desc = 'Block window processing'):
        data = src.read(1, window = window, masked = True)

        total_high_suitability += np.count_nonzero((data > 8) & (data <= 10)) # Counts total number of cells >8 & <=10

        total_nodata += np.sum(data.mask) # Calculates the total number of nodata cells

    all_cells = src.width * src.height # Total number of cells

    all_NON_nodata_cells = all_cells - total_nodata # Total number of cells WITH valid data

    percent_high_suitability = total_high_suitability / all_NON_nodata_cells 
    print(f'Total number of valid data cells: {all_NON_nodata_cells}')
    print(f'% high suitability (>8 & <=10): {percent_high_suitability}')
# Out:
# Total blocks: 910224
# Block window processing: 100%|██████████| 910224/910224 [05:32<00:00, 2737.38it/s]
# Total number of valid data cells: 8565940668
# % high suitability (>8 & <=10): 0.25539928325359257
